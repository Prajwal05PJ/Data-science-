# %%
# Import the pandas library for data manipulation and analysis
import pandas as pd

# Load the dataset into a pandas DataFrame
df=pd.read_csv('/content/ToyotaCorolla - MLR.csv')
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
# Display a statistical summary of the DataFrame
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
# Drop columns with any missing values from the DataFrame
df.dropna(axis=1,inplace=True)
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
# Drop the 'Fuel_Type' column from the DataFrame
df.drop(['Fuel_Type'],axis=1,inplace=True)
df
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
# Import matplotlib for plotting
import matplotlib.pyplot as plt
# Import seaborn for enhanced data visualization
import seaborn as sns
# Loop through each column in the DataFrame to identify and visualize outliers
for i in df.columns:
  Q1=df[i].quantile(0.25) # Calculate the first quartile (25th percentile) for the current column
  Q3=df[i].quantile(0.75) # Calculate the third quartile (75th percentile) for the current column
  IQR=Q3-Q1               # Calculate the interquartile range (IQR) for the current column
  # Calculate the lower limit for identifying outliers
  lower_limit=Q1-1.5*IQR
  # Calculate the upper limit for identifying outliers
  upper_limit=Q3+1.5*IQR
  # Identify outliers in the current column
  outliers=df[(df[i]<lower_limit) | (df[i]>upper_limit)]
  # Plot a boxplot for the current column to visualize outliers
  plt.figure(figsize=(10,5)) # Set the figure size for the plot
  sns.boxplot(df[i])         # Create a boxplot using seaborn for the current column
  plt.show()                 # Display the plot

# %%
# Generate pair plots to visualize relationships between pairs of numerical variables
sns.pairplot(df)
plt.show()

# %%
# Plot histograms for each column in the DataFrame
for i in df.columns:
  plt.hist(df[i],bins=10,edgecolor='black') # Create a histogram with 10 bins and black edges
  plt.title(i)                              # Set the title of the plot as the name of the current column
  plt.show()                                # Display the plot

# %%
# Generate a heatmap to visualize the correlation matrix
sns.heatmap(df.corr(),annot=True,fmt='.2f')# Create a heatmap using seaborn
plt.title('correlation heatmap')# Set the title of the heatmap
plt.show()# Display the plot

# %%
# Import the train_test_split function from scikit-learn
from sklearn.model_selection import train_test_split
# Define the feature matrix (X) and the target variable (y)
x=df.drop(columns=['Price'])
y=df['Price']

# %%
# Split the data into training and testing sets (80% training, 20% testing)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(y_test)
print(x_test)
# Out:
# 651      7950
# 411     10950
# 342     14950
# 1298     7500
# 483      9900
#         ...
# 1029    10450
# 520      9400
# 996      9950
# 333     11750
# 1069     7950
# Name: Price, Length: 288, dtype: int64
#       Age_08_04      KM   HP  Automatic    cc  Doors  Cylinders  Gears  Weight
# 651          68  115071  110          0  1600      3          4      5    1055
# 411          52   99323  110          0  1600      3          4      5    1055
# 342          42   29640  110          0  1600      3          4      5    1055
# 1298         78   71186  110          0  1600      3          4      5    1050
# 483          56   62751  110          0  1600      3          4      5    1050
# ...         ...     ...  ...        ...   ...    ...        ...    ...     ...
# 1029         58   30634  110          0  1600      5          4      5    1075
# 520          54   50000   97          0  1400      3          4      5    1025
# ...

# %% [markdown]
# **Building a multiple linear regression model**

# %%
 # Import the LinearRegression class from scikit-learn
from sklearn.linear_model import LinearRegression
 # Import evaluation metrics
from sklearn.metrics import mean_squared_error,r2_score
# Create and train the model
model = LinearRegression()
model.fit(x_train, y_train)

# Make predictions
y_pred=model.predict(x_test)

#Evaluate the model
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

#Printing the Performance
print("Model Performance")
print("Mean squared error:",mse)
print("R2 Score:",r2)
# Out:
# Model Performance
# Mean squared error: 3218676.811517265
# R2 Score: 0.7413115275215344

# %%
# Import Lasso and Ridge regression models from scikit-learn
from sklearn.linear_model import Lasso, Ridge
 # Import cross_val_score for cross-validation
from sklearn.model_selection import cross_val_score

#Lasso Regression
# Create a Lasso regression model with alpha=0.1
lasso=Lasso(alpha=0.1)
lasso.fit(x_train,y_train) # Fit the Lasso model on the training data
y_pred_lasso=lasso.predict(x_test)# Make predictions on the test data using the Lasso model
# Calculate the mean squared error for the Lasso model
mse_lasso=mean_squared_error(y_test,y_pred_lasso)
# Calculate the R-squared value for the Lasso model
r2_lasso=r2_score(y_test,y_pred_lasso)
#Printing the Performance
print("Lasso Regression performance")
print("Mean squared error:",mse_lasso)
print("R-squared",r2_lasso)

#Ridge Regression
# Create a Ridge regression model with alpha=0.1
ridge=Ridge(alpha=0.1)
ridge.fit(x_train,y_train)# Fit the Ridge model on the training data
y_pred_ridge=ridge.predict(x_test)# Make predictions on the test data using the Ridge model
# Calculate the mean squared error for the Ridge model
mse_ridge=mean_squared_error(y_test,y_pred_ridge)
# Calculate the R-squared value for the Ridge model
r2_ridge=r2_score(y_test,y_pred_ridge)
#Printing the performance
print("\nRidge Regression performance")
print("Mean squared error:",mse_lasso)
print("R-squared",r2_lasso)
# Out:
# Lasso Regression performance
# Mean squared error: 3219665.486846491
# R-squared 0.7412320666356885
#
# Ridge Regression performance
# Mean squared error: 3219665.486846491
# R-squared 0.7412320666356885

# %% [markdown]
# Data Loading and Preparation:
#
# Loads the dataset into a DataFrame.
# Displays the first few rows and a statistical summary.
# Drops columns with missing values and the 'Fuel_Type' column.
#
# Exploratory Data Analysis (EDA):
#
# Identifies and visualizes outliers in each column using boxplots.
# Generates pair plots to visualize relationships between numerical variables.
# Creates histograms for each column.
# Generates a heatmap to visualize the correlation matrix.
#
# Model Building:
#
# Splits the dataset into training and testing sets (80% training, 20% testing).
# Builds and trains a multiple linear regression model.
# Evaluates the model's performance using mean squared error and R-squared value.
# Overall, the code prepares the data, performs EDA, and builds a linear regression model to predict car prices.
#
# Lasso Regression:
#
# Creates a Lasso regression model with an alpha value of 0.1.
# Fits the Lasso model on the training data.
# Makes predictions on the test data using the Lasso model.
# Calculates and prints the mean squared error and R-squared value for the Lasso model.
#
# Ridge Regression:
#
# Creates a Ridge regression model with an alpha value of 0.1.
# Fits the Ridge model on the training data.
# Makes predictions on the test data using the Ridge model.
# Calculates and prints the mean squared error and R-squared value for the Ridge model.
