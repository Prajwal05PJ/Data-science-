# %% [markdown]
# **1. Data Exploration:**

# %%
import pandas as pd
df1=pd.read_csv('/content/Titanic_test.csv')
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df2=pd.read_csv('/content/Titanic_train.csv')
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df1.describe(include=['O'])
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df2.describe(include=['O'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df1.drop('PassengerId',axis=1,inplace=True)
df1_numeric = df1.select_dtypes(include=["int64", "float64"])
df1_numeric
# Out:
#      Pclass   Age  SibSp  Parch      Fare
# 0         3  34.5      0      0    7.8292
# 1         3  47.0      1      0    7.0000
# 2         2  62.0      0      0    9.6875
# 3         3  27.0      0      0    8.6625
# 4         3  22.0      1      1   12.2875
# ..      ...   ...    ...    ...       ...
# 413       3   NaN      0      0    8.0500
# 414       1  39.0      0      0  108.9000
# 415       3  38.5      0      0    7.2500
# 416       3   NaN      0      0    8.0500
# 417       3   NaN      1      1   22.3583
#
# [418 rows x 5 columns]

# %%
df2.drop('PassengerId',axis=1,inplace=True)
df2_numeric = df2.select_dtypes(include=["int64", "float64"])
df2_numeric
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for i in df1_numeric.columns:
  plt.hist(df1_numeric[i],bins=10,edgecolor='black')
  plt.title(i)
  plt.show()

# %%
for i in df2_numeric.columns:
  plt.hist(df2_numeric[i],bins=10,edgecolor='black')
  plt.title(i)
  plt.show()

# %%
for i in df1_numeric.columns:
  Q1=df1_numeric[i].quantile(0.25)
  Q3=df1_numeric[i].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  outliers=df1[(df1_numeric[i]<lower_limit) | (df1_numeric[i]>upper_limit)]
  plt.figure(figsize=(10,5))
  sns.boxplot(x=df1_numeric[i])
  plt.title(i)
  plt.xlabel(i)
  plt.show()

# %%
for i in df2_numeric.columns:
  Q1=df2_numeric[i].quantile(0.25)
  Q3=df2_numeric[i].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  outliers=df1[(df2_numeric[i]<lower_limit) | (df2_numeric[i]>upper_limit)]
  plt.figure(figsize=(10,5))
  sns.boxplot(x=df2_numeric[i],color='lightgreen')
  plt.title(i)
  plt.xlabel(i)
  plt.show()
# Out:
# <ipython-input-38-634692e36fab>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   outliers=df1[(df2_numeric[i]<lower_limit) | (df2_numeric[i]>upper_limit)]
# <ipython-input-38-634692e36fab>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   outliers=df1[(df2_numeric[i]<lower_limit) | (df2_numeric[i]>upper_limit)]
# <ipython-input-38-634692e36fab>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   outliers=df1[(df2_numeric[i]<lower_limit) | (df2_numeric[i]>upper_limit)]
# <ipython-input-38-634692e36fab>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   outliers=df1[(df2_numeric[i]<lower_limit) | (df2_numeric[i]>upper_limit)]
# <ipython-input-38-634692e36fab>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   outliers=df1[(df2_numeric[i]<lower_limit) | (df2_numeric[i]>upper_limit)]
# ...

# %%
sns.pairplot(df1_numeric)
plt.show()

# %%
sns.pairplot(df2_numeric)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df1_numeric.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df2_numeric.corr(),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# **Summary**
# Loading the Dataset: We loaded the Titanic test and Titanic train datasets using pandas.
#
# Exploratory Data Analysis:
#
# Examine Features: Used describe() to understand summary statistics.
#
# Visualizations: Created histograms, box plots, pair plots, and a correlation heatmap to visualize distributions and relationships between features.
#
# Analysis: Analyzed patterns or correlations based on the visualizations and summary statistics.

# %% [markdown]
# **2. Data Preprocessing:**

# %%
missing_values1=df1.isnull().sum()
missing_values1
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %%
for i in df1.select_dtypes(include=['int64','float64']).columns:
  df1[i].fillna(df1[i].mean(),inplace=True)
for i in df1.select_dtypes(include=['object']).columns:
  df1[i].fillna(df1[i].mode()[0],inplace=True)
df1.isnull().sum()
# Out:
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
missing_values2=df2.isnull().sum()
missing_values2
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
for i in df2.select_dtypes(include=['int64','float64']).columns:
  df2[i].fillna(df2[i].mean(),inplace=True)
for i in df2.select_dtypes(include=['object']).columns:
  df2[i].fillna(df2[i].mode()[0],inplace=True)
df2.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
df2 = pd.get_dummies(df2)
df1 = pd.get_dummies(df1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

x=df1.drop(columns=['Pclass'],axis=1)
y=df1['Pclass']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

model=LogisticRegression(max_iter=1000)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print("Accuracy Score=",accuracy_score(y_test,y_pred))
print("Confusion matrix=\n",confusion_matrix(y_test,y_pred))
print("Classification report=\n",classification_report(y_test,y_pred))
# Out:
# Accuracy Score= 0.75
# Confusion matrix=
#  [[17  4  0]
#  [ 1  7 13]
#  [ 1  2 39]]
# Classification report=
#                precision    recall  f1-score   support
#
#            1       0.89      0.81      0.85        21
#            2       0.54      0.33      0.41        21
#            3       0.75      0.93      0.83        42
#
#     accuracy                           0.75        84
#    macro avg       0.73      0.69      0.70        84
# weighted avg       0.73      0.75      0.73        84

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

x=df2.drop(columns=['Survived'],axis=1)
y=df2['Survived']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

model=LogisticRegression(max_iter=1000)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print("Accuracy Score=",accuracy_score(y_test,y_pred))
print("Confusion matrix=\n",confusion_matrix(y_test,y_pred))
print("Classification report=\n",classification_report(y_test,y_pred))
# Out:
# Accuracy Score= 0.8212290502793296
# Confusion matrix=
#  [[92 13]
#  [19 55]]
# Classification report=
#                precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       105
#            1       0.81      0.74      0.77        74
#
#     accuracy                           0.82       179
#    macro avg       0.82      0.81      0.81       179
# weighted avg       0.82      0.82      0.82       179

# %%
from sklearn.metrics import precision_score, recall_score,f1_score,roc_auc_score,roc_curve

y_pred_proba = model.predict_proba(x_test)[:, 1]
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
f1=f1_score(y_test,y_pred)
roc_auc=roc_auc_score(y_test,y_pred_proba)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")
print(f"ROC-AUC: {roc_auc}")
# Out:
# Precision: 0.8088235294117647
# Recall: 0.7432432432432432
# F1-score: 0.7746478873239436
# ROC-AUC: 0.8985842985842987

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_proba)
plt.plot(fpr,tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()

# %%
import numpy as np

# Feature names
feature_names = x.columns

# Coefficients from the logistic regression model
coefficients = model.coef_[0]

# Create a DataFrame to display feature names and their corresponding coefficients
coef_df = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient': coefficients
})

# Calculate the odds ratios
coef_df['Odds Ratio'] = np.exp(coef_df['Coefficient'])

# Sort by the absolute value of the coefficient for better interpretability
coef_df = coef_df.sort_values(by='Coefficient', ascending=False)

print(coef_df)
# Out:
#                 Feature  Coefficient  Odds Ratio
# 978         Ticket_1601     1.541601    4.672063
# 896          Sex_female     1.419980    4.137039
# 1460  Ticket_C.A. 37671     1.106351    3.023307
# 1135       Ticket_29106     0.940805    2.562042
# 1339      Ticket_367226     0.921942    2.514167
# ...                 ...          ...         ...
# 1641      Cabin_C22 C26    -0.831814    0.435259
# 1091        Ticket_2665    -0.847761    0.428373
# 1293      Ticket_349909    -0.922449    0.397544
# 1231      Ticket_347082    -0.931112    0.394115
# 897            Sex_male    -1.425441    0.240402
#
# [1729 rows x 3 columns]

# %% [markdown]
# **Positive Coefficients**
#
# 1)Ticket_1601
#
# Coefficient: 1.541761
#
# Odds Ratio: 4.672810
#
# Interpretation: Having the ticket "1601" increases the log-odds of survival by 1.54. The odds of survival are approximately 4.67 times higher for passengers with this ticket compared to those without it.
#
# 2)Sex_female
#
# Coefficient: 1.429309
#
# Odds Ratio: 4.175811
#
# Interpretation: Being female increases the log-odds of survival by 1.43. The odds of survival are approximately 4.18 times higher for females compared to males.
#
# 3)Ticket_C.A. 37671
#
# Coefficient: 1.107330
#
# Odds Ratio: 3.026268
#
# Interpretation: Having the ticket "C.A. 37671" increases the log-odds of survival by 1.11. The odds of survival are approximately 3.03 times higher for passengers with this ticket compared to those without it.
#
# **Negative Coefficients**
#
# 1)Ticket_2665
#
# Coefficient: -0.847707
#
# Odds Ratio: 0.428396
#
# Interpretation: Having the ticket "2665" decreases the log-odds of survival by 0.85. The odds of survival are approximately 0.43 times (or 57% less) for passengers with this ticket compared to those without it.
#
# 2)Ticket_347054
#
# Coefficient: -0.848613
#
# Odds Ratio: 0.428008
#
# Interpretation: Having the ticket "347054" decreases the log-odds of survival by 0.85. The odds of survival are approximately 0.43 times (or 57% less) for passengers with this ticket compared to those without it.
#
# 3)Sex_male
#
# Coefficient: -1.412916
#
# Odds Ratio: 0.243432
#
# Interpretation: Being male decreases the log-odds of survival by 1.41. The odds of survival are approximately 0.24 times (or 76% less) for males compared to females.
